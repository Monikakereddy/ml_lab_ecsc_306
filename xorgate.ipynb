# %%
#!/usr/bin/env PYTHONIOENCODING="utf-8" python
"""
A simple neural network learning the XOR function
"""
import tensorflow as tf
sess = tf.InteractiveSession()

# Desired input output mapping of XOR function:
x_ = [[0, 0], [0, 1], [1, 0], [1, 1]] # input
#labels=[0,      1,      1,      0]   # output =>
expect=[[1,0],  [0,1],  [0,1], [1,0]] # ONE HOT REPRESENTATION! 'class' [1,0]==0 [0,1]==1

# x = tf.Variable(x_)
x = tf.placeholder("float", [None,2]) #  can we feed directly?
y_ = tf.placeholder("float", [None, 2]) # two output classes

number_hidden_nodes = 20 # 20 outputs to create some room for negatives and positives

W = tf.Variable(tf.random_uniform([2, number_hidden_nodes], -.01, .01))
b = tf.Variable(tf.random_uniform([number_hidden_nodes], -.01, .01))
hidden  = tf.nn.relu(tf.matmul(x,W) + b) # first layer.

 # the XOR function is the first nontrivial function, for which a two layer network is needed.
W2 = tf.Variable(tf.random_uniform([number_hidden_nodes,2], -.1, .1))
b2 = tf.Variable(tf.zeros([2]))
hidden2 = tf.matmul(hidden, W2)#+b2

y = tf.nn.softmax(hidden2)


# Define loss and optimizer
cross_entropy = -tf.reduce_sum(y_*tf.log(y))
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(cross_entropy)

# Train
tf.initialize_all_variables().run()
for step in range(1000):
    feed_dict={x: x_, y_:expect } # feed the net with our inputs and desired outputs.
    e,a=sess.run([cross_entropy,train_step],feed_dict)
    if e<1:break # early stopping yay
    print("step %d : entropy %s"%(step,e)) # error/loss should decrease over time


# Test trained model
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1)) # argmax along dim-1
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) # [True, False, True, True] -> [1,0,1,1] -> 0.75.

print("accuracy %s"%(accuracy.eval({x: x_, y_: expect})))

learned_output=tf.argmax(y,1)
print(learned_output.eval({x: x_}))
# Out:
# WARNING:tensorflow:From /Anaconda/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0 : entropy 2.77264
# step 1 : entropy 2.77227
# step 2 : entropy 2.77209
# step 3 : entropy 2.77194
# step 4 : entropy 2.77159
# step 5 : entropy 2.77151
# step 6 : entropy 2.77131
# step 7 : entropy 2.77084
# step 8 : entropy 2.77075
# step 9 : entropy 2.77035
# step 10 : entropy 2.76975
# step 11 : entropy 2.76952
# step 12 : entropy 2.76891
# step 13 : entropy 2.76797
# step 14 : entropy 2.76765
# step 15 : entropy 2.76655
# step 16 : entropy 2.76519
# step 17 : entropy 2.76457
# step 18 : entropy 2.76283
# step 19 : entropy 2.76066
# step 20 : entropy 2.75972
# step 21 : entropy 2.75675
# step 22 : entropy 2.75352
# step 23 : entropy 2.75176
# step 24 : entropy 2.74715
# step 25 : entropy 2.74187
# step 26 : entropy 2.73927
# step 27 : entropy 2.73147
# step 28 : entropy 2.72372
# step 29 : entropy 2.71855
# step 30 : entropy 2.70732
# step 31 : entropy 2.69389
# step 32 : entropy 2.68764
# step 33 : entropy 2.66748
# step 34 : entropy 2.65059
# step 35 : entropy 2.63443
# step 36 : entropy 2.61209
# step 37 : entropy 2.57669
# step 38 : entropy 2.56686
# step 39 : entropy 2.51552
# step 40 : entropy 2.48673
# step 41 : entropy 2.42857
# step 42 : entropy 2.39933
# step 43 : entropy 2.3237
# step 44 : entropy 2.3028
# step 45 : entropy 2.26159
# step 46 : entropy 2.13551
# step 47 : entropy 2.08762
# step 48 : entropy 2.04113
# step 49 : entropy 1.99758
# step 50 : entropy 1.95165
# step 51 : entropy 1.81426
# step 52 : entropy 1.74255
# step 53 : entropy 1.70856
# step 54 : entropy 1.66808
# step 55 : entropy 1.54748
# step 56 : entropy 1.48816
# step 57 : entropy 1.45485
# step 58 : entropy 1.41676
# step 59 : entropy 1.40893
# step 60 : entropy 1.2742
# step 61 : entropy 1.23685
# step 62 : entropy 1.2104
# step 63 : entropy 1.10613
# step 64 : entropy 1.07058
# step 65 : entropy 1.09562
# step 66 : entropy 1.05814
# accuracy 1.0
# [0 1 1 0]
